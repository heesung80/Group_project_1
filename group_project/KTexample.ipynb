# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
import random
from group_project/api_keys.py import cid
from group_project/api_keys.py import secret

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []

#set up counter:
#when we collect 15,000 tracks,one second pause

track_counter=0
for i in range(0,2000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        #print(artist_name)
        track_counter+=1
        if track_counter==1500:
                time.sleep(1.0)
                track_counter=0
        else:
            continue

# %%
artist_name = []
track_name = []
popularity = []
track_id = []

#set up counter:
#when we collect 15,000 tracks,one second pause

track_counter=0
for i in range(0,1500):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        #print(artist_name)
        track_counter+=1
       #if track_counter==1500:
        #time.sleep(1.0)
                #track_counter=0
        #else:
            #continue
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     751             while True:
# --> 752                 self._update_chunk_length()
#     753                 if self.chunk_left == 0:
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     681             return
# --> 682         line = self._fp.fp.readline()
#     683         line = line.split(b";", 1)[0]
#
# ~\.conda\envs\PythonDataViz\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
# --> 326                 raise timeout("The read operation timed out")
#     327             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~\.conda\envs\PythonDataViz\lib\site-packages\requests\models.py in generate()
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     559         if self.chunked and self.supports_chunked_reads():
# --> 560             for line in self.read_chunked(amt, decode_content=decode_content):
#     561                 yield line
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     780             if self._original_response:
# --> 781                 self._original_response.close()
#     782
#
# ~\.conda\envs\PythonDataViz\lib\contextlib.py in __exit__(self, type, value, traceback)
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     429                 # there is yet no clean way to get at it from this context.
# --> 430                 raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     431
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-20-9a218f8491e3> in <module>
#       9 track_counter=0
#      10 for i in range(0,1500):
# ---> 11     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#      12     for i, t in enumerate(track_results['tracks']['items']):
#      13         artist_name.append(t['artists'][0]['name'])
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\spotipy\client.py in search(self, q, limit, offset, type, market)
#     457         """
#     458         return self._get(
# --> 459             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     460         )
#     461
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     205             kwargs.update(args)
#     206
# --> 207         return self._internal_call("GET", url, payload, kwargs)
#     208
#     209     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     167             response = self._session.request(
#     168                 method, url, headers=headers, proxies=self.proxies,
# --> 169                 timeout=self.requests_timeout, **args
#     170             )
#     171
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~\.conda\envs\PythonDataViz\lib\site-packages\requests\models.py in generate()
#     756                     raise ContentDecodingError(e)
#     757                 except ReadTimeoutError as e:
# --> 758                     raise ConnectionError(e)
#     759             else:
#     760                 # Standard file-like object.
#
# ConnectionError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out.

# %%
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})

track_dataframe
# Out:
#         artist_name                             track_name  \
# 0     Trevor Daniel                                Falling
# 1      Travis Scott                             SICKO MODE
# 2        Juice WRLD                           Lucid Dreams
# 3        Juice WRLD                 All Girls Are The Same
# 4     Billie Eilish                   lovely (with Khalid)
# ...             ...                                    ...
# 1995      Meek Mill  What's Free (feat. Rick Ross & Jay Z)
# 1996  Alec Benjamin                                  Steve
# 1997   Always Never                                 Wylin'
# 1998    Point North                                 Hammer
# 1999       Granular                Brown Noise For Sleep 1
#
#                     track_id  popularity
# 0     4TnjEaWOeW0eKTKIEvJyCa          94
# 1     2xLMifQCjDGFmkHkpNLD9h          93
# 2     285pBltuF7vW8TeWk8hdRR          89
# 3     4VXIryQMWpIdGgYR4TrjT1          85
# 4     0u2P5u6lvoDfwTYjAADbn4          90
# ...                      ...         ...
# 1995  4iQ5gmTAzWfK8JyFC2LBox          59
# 1996  211LaT5hzPOKolVtgzwWnq          62
# 1997  3BymIH6QBGllSijMm3sQiR          60
# 1998  0j80OMNnPlSWUwLoJkB1JR          59
# 1999  7HGIUGjNmAATN4om7BMcci          60
#
# [2000 rows x 4 columns]
